# %%
import pandas as pd

df = pd.read_csv("./breast_cancer.csv")

df.head()

df["diagnosis"] = df["diagnosis"].map({"M": 1, "B": 0})     

df.head(100)
# Out:
#           ID  diagnosis  mean_radius  mean_texture  mean_perimeter  mean_area  \
# 0     842302          1       17.990         10.38          122.80     1001.0
# 1     842517          1       20.570         17.77          132.90     1326.0
# 2   84300903          1       19.690         21.25          130.00     1203.0
# 3   84348301          1       11.420         20.38           77.58      386.1
# 4   84358402          1       20.290         14.34          135.10     1297.0
# ..       ...        ...          ...           ...             ...        ...
# 95     86208          1       20.260         23.03          132.40     1264.0
# 96     86211          0       12.180         17.84           77.79      451.1
# 97    862261          0        9.787         19.94           62.11      294.5
# 98    862485          0       11.600         12.84           74.34      412.6
# 99    862548          1       14.420         19.77           94.48      642.5
#
#     mean_smoothness  mean_compactness  mean_concavity  mean_concavity_points  \
# 0           0.11840           0.27760        0.300100               0.147100
# 1           0.08474           0.07864        0.086900               0.070170
# 2           0.10960           0.15990        0.197400               0.127900
# 3           0.14250           0.28390        0.241400               0.105200
# 4           0.10030           0.13280        0.198000               0.104300
# ..              ...               ...             ...                    ...
# 95          0.09078           0.13130        0.146500               0.086830
# 96          0.10450           0.07057        0.024900               0.029410
# 97          0.10240           0.05301        0.006829               0.007937
# 98          0.08983           0.07525        0.041960               0.033500
# 99          0.09752           0.11410        0.093880               0.058390
#
#     ...  worst_radius  worst_texture  worst_perimeter  worst_area  \
# 0   ...         25.38          17.33           184.60      2019.0
# 1   ...         24.99          23.41           158.80      1956.0
# 2   ...         23.57          25.53           152.50      1709.0
# 3   ...         14.91          26.50            98.87       567.7
# 4   ...         22.54          16.67           152.20      1575.0
# ..  ...           ...            ...              ...         ...
# 95  ...         24.22          31.59           156.10      1750.0
# 96  ...         12.83          20.92            82.14       495.2
# 97  ...         10.92          26.29            68.81       366.1
# 98  ...         13.06          17.16            82.96       512.5
# 99  ...         16.33          30.86           109.50       826.4
#
#     worst_smoothness  worst_compactness  worst_concavity  \
# 0             0.1622            0.66560          0.71190
# 1             0.1238            0.18660          0.24160
# 2             0.1444            0.42450          0.45040
# 3             0.2098            0.86630          0.68690
# 4             0.1374            0.20500          0.40000
# ..               ...                ...              ...
# 95            0.1190            0.35390          0.40980
# 96            0.1140            0.09358          0.04980
# 97            0.1316            0.09473          0.02049
# 98            0.1431            0.18510          0.19220
# 99            0.1431            0.30260          0.31940
#
#     worst_concavity_points  worst_symmetry  worst_fractal_dimension
# 0                  0.26540          0.4601                  0.11890
# 1                  0.18600          0.2750                  0.08902
# 2                  0.24300          0.3613                  0.08758
# 3                  0.25750          0.6638                  0.17300
# 4                  0.16250          0.2364                  0.07678
# ..                     ...             ...                      ...
# 95                 0.15730          0.3689                  0.08368
# 96                 0.05882          0.2227                  0.07376
# 97                 0.02381          0.1934                  0.08988
# 98                 0.08449          0.2772                  0.08756
# 99                 0.15650          0.2718                  0.09353
#
# [100 rows x 32 columns]

# %%
import pandas as pd
import statsmodels.api as sm

# Predictors selected to reduce multicollinearity
predictors = [
    "mean_perimeter",
    "mean_symmetry",
    "worst_radius",
    "worst_texture",
    "worst_concavity_points",
    "worst_symmetry",
]

X = df[predictors].copy()
y = df["diagnosis"].astype(int)

X_const = sm.add_constant(X)
logit_model = sm.Logit(y, X_const)
result = logit_model.fit(disp=False)

coef_table = pd.DataFrame({
    "coefficient": result.params,
    "std_error": result.bse,
    "p_value": result.pvalues,
})

print("Logistic Regression Coefficients (Malignant = 1)")
display(coef_table)

print("\nModel summary:")
print(result.summary())
# Out:
# Logistic Regression Coefficients (Malignant = 1)
#                         coefficient  std_error       p_value
# const                    -35.987825   5.352078  1.767001e-11
# mean_perimeter            -0.093649   0.069357  1.769362e-01
# mean_symmetry             22.461451  18.757869  2.311345e-01
# worst_radius               1.719531   0.453860  1.514498e-04
# worst_texture              0.275469   0.054761  4.894084e-07
# worst_concavity_points    41.989078  10.193140  3.799479e-05
# worst_symmetry            -0.650972   7.378947  9.297016e-01
# Model summary:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              diagnosis   No. Observations:                  569
# Model:                          Logit   Df Residuals:                      562
# Method:                           MLE   Df Model:                            6
# Date:                Fri, 13 Mar 2026   Pseudo R-squ.:                  0.8714
# Time:                        11:28:44   Log-Likelihood:                -48.300
# converged:                       True   LL-Null:                       -375.72
# Covariance Type:            nonrobust   LLR p-value:                3.430e-138
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                    -35.9878      5.352     -6.724      0.000     -46.478     -25.498
# mean_perimeter            -0.0936      0.069     -1.350      0.177      -0.230       0.042
# mean_symmetry             22.4615     18.758      1.197      0.231     -14.303      59.226
# worst_radius               1.7195      0.454      3.789      0.000       0.830       2.609
# worst_texture              0.2755      0.055      5.030      0.000       0.168       0.383
# worst_concavity_points    41.9891     10.193      4.119      0.000      22.011      61.967
# worst_symmetry            -0.6510      7.379     -0.088      0.930     -15.113      13.811
# ==========================================================================================
#
# Possibly complete quasi-separation: A fraction 0.33 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
