# %% [markdown]
# # Stage 1 — Environment Setup
#
# Build an LLM from scratch, trained on the Mahabharata corpus.
#
# Pipeline:
# 1. **Env setup** (this notebook)
# 2. Data collection (Kaggle: `tilakd/mahabharata`)
# 3. Data prep & preprocessing
# 4. Tokenization (Byte-Pair Encoding)
# 5. Coding attention (scaled dot-product → multi-head causal)
#
# Reference: [Build LLMs from scratch — Kaggle](https://www.kaggle.com/code/zeyadusf/llms-from-scratch) (based on Sebastian Raschka's book).

# %% [markdown]
# ## Install dependencies
# Run once. From the `customLLM/` folder.

# %%
# %pip install -q -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Verify the environment

# %%
import sys, platform
from importlib.metadata import version
import torch
import numpy as np
import pandas as pd
import tiktoken  # noqa: F401
import kagglehub  # noqa: F401

print(f'Python      : {sys.version.split()[0]}')
print(f'Platform    : {platform.platform()}')
print(f'torch       : {torch.__version__}')
print(f'numpy       : {np.__version__}')
print(f'pandas      : {pd.__version__}')
print(f'tiktoken    : {version("tiktoken")}')
print(f'kagglehub   : {version("kagglehub")}')

# Pick best available device (Apple MPS, CUDA, or CPU).
if torch.cuda.is_available():
    device = 'cuda'
elif torch.backends.mps.is_available():
    device = 'mps'
else:
    device = 'cpu'
print(f'device      : {device}')
# Out:
# Python      : 3.13.11
# Platform    : macOS-26.3.1-arm64-arm-64bit-Mach-O
# torch       : 2.10.0
# numpy       : 2.4.4
# pandas      : 3.0.1
# tiktoken    : 0.13.0
# kagglehub   : 0.3.13
# device      : mps

# %% [markdown]
# ## Reproducibility seed

# %%
import random
SEED = 123
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
print('seed set:', SEED)
# Out:
# seed set: 123

# %% [markdown]
# Next: `02_data_collection.ipynb` — pull the Mahabharata corpus from Kaggle.
